# %%
import matplotlib.pyplot as plt
import numpy as np 
import os, sys
from collections import Counter

os.chdir('/share/Documents/project/onn-digital')
print(os.getcwd())
# Out:
# /share/Documents/project/onn-digital

# %%
def show(data, title):
    print(Counter(data))  # 直接显示数据出现频次
    print()

    plt.hist(data)
    plt.title(title)
    plt.show()

# %%
w1 = np.load('log_tf/npy/w1.npy').reshape(-1)
show(w1, 'w1')
# Out:
# Counter({-3.0: 40895, 3.0: 10203, 2.0: 23, -2.0: 23, -1.0: 23, 0.0: 19, 1.0: 14})

# %%
w2 = np.load('log_tf/npy/w2.npy').reshape(-1)
show(w1, 'w2')
# Out:
# Counter({-3.0: 40895, 3.0: 10203, 2.0: 23, -2.0: 23, -1.0: 23, 0.0: 19, 1.0: 14})

# %%
frequency = np.load('log_tf/npy/frequency.npy').reshape(-1)
show(frequency, 'frequency')
# Out:
# Counter({20.0: 3599688, 30.0: 876442, 10.0: 627076, 0.0: 11671, 40.0: 5093, -10.0: 30})

# %%
counters1 = np.load('log_tf/npy/counters1.npy').reshape(-1)
show(counters1, 'counters1')
# Out:
# Counter({4.0: 721116, 5.0: 35308, 6.0: 26874, 7.0: 21646, 12.0: 19720, 11.0: 19705, 10.0: 19678, 14.0: 19413, 8.0: 19325, 9.0: 19249, 13.0: 18887, 15.0: 18621, 16.0: 16382, 17.0: 12705, 18.0: 11056, 19.0: 315})

# %%
counters2 = np.load('log_tf/npy/counters2.npy').reshape(-1)
show(counters2, 'counters2')
# Out:
# Counter({1.0: 3599688, 2.0: 876442, 0.0: 627076, -1.0: 11701, 3.0: 5093})

# %%
countersWdiv4n = np.load('log_tf/npy/countersWdiv4n.npy').reshape(-1)
show(countersWdiv4n, 'countersWdiv4n')
# Out:
# Counter({-3.0: 3599688, -2.0: 876442, -4.0: 627076, -5.0: 11671, -1.0: 5093, -6.0: 30})
