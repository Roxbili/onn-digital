# %%
import matplotlib.pyplot as plt
import numpy as np 
import os, sys
from collections import Counter

os.chdir('/share/Documents/project/onn-digital')
print(os.getcwd())

npy_dir = 'log_tf/npy_e_noAdd3'
# Out:
# /share/Documents/project/onn-digital

# %%
def show(data, title):
    print(Counter(data))  # 直接显示数据出现频次
    print()

    plt.hist(data)
    plt.title(title)
    plt.show()

# %%
w1 = np.load(os.path.join(npy_dir, 'w1.npy')).reshape(-1)
show(w1, 'w1')
# Out:
# Counter({-3.0: 14706, 3.0: 13397, 0.0: 5305, -1.0: 5050, 1.0: 4984, -2.0: 4076, 2.0: 3682})

# %%
w2 = np.load(os.path.join(npy_dir, 'w2.npy')).reshape(-1)
show(w1, 'w2')
# Out:
# Counter({-3.0: 14706, 3.0: 13397, 0.0: 5305, -1.0: 5050, 1.0: 4984, -2.0: 4076, 2.0: 3682})

# %%
frequency = np.load(os.path.join(npy_dir, 'frequency.npy')).reshape(-1)
show(frequency, 'frequency')
# Out:
# Counter({-0.0: 3594114, 200.0: 833549, 10.0: 52395, 20.0: 50255, 30.0: 48071, 40.0: 45945, 50.0: 44475, 60.0: 42748, 70.0: 40931, 80.0: 39270, 90.0: 37809, 100.0: 36038, 110.0: 34365, 120.0: 32640, 130.0: 31142, 140.0: 29601, 150.0: 28546, 160.0: 26774, 170.0: 25266, 180.0: 23721, 190.0: 22345})

# %%
counters1 = np.load(os.path.join(npy_dir, 'counters1.npy')).reshape(-1)
show(counters1, 'counters1')
# Out:
# Counter({4.0: 721116, 5.0: 35308, 6.0: 26874, 7.0: 21646, 12.0: 19720, 11.0: 19705, 10.0: 19678, 14.0: 19413, 8.0: 19325, 9.0: 19249, 13.0: 18887, 15.0: 18621, 16.0: 16382, 17.0: 12705, 18.0: 11056, 19.0: 315})

# %%
counters2 = np.load(os.path.join(npy_dir, 'counters2.npy')).reshape(-1)
show(counters2, 'counters2')
# Out:
# Counter({-0.0: 3646509, 19.0: 833549, 1.0: 50255, 2.0: 48071, 3.0: 45945, 4.0: 44475, 5.0: 42748, 6.0: 40931, 7.0: 39270, 8.0: 37809, 9.0: 36038, 10.0: 34365, 11.0: 32640, 12.0: 31142, 13.0: 29601, 14.0: 28546, 15.0: 26774, 16.0: 25266, 17.0: 23721, 18.0: 22345})

# %%
countersWdiv4n = np.load(os.path.join(npy_dir, 'countersWdiv4n.npy')).reshape(-1)
show(countersWdiv4n, 'countersWdiv4n')
# Out:
# Counter({-19.0: 2710135, 15.0: 833549, -17.0: 68830, -18.0: 68524, -16.0: 68192, -15.0: 67265, -14.0: 66350, -13.0: 65662, -12.0: 64805, -11.0: 63549, -10.0: 62254, -9.0: 60939, -8.0: 59451, -7.0: 58097, -6.0: 55479, -5.0: 54582, -4.0: 52395, -3.0: 50255, -2.0: 48071, -1.0: 45945, 0.0: 44475, 1.0: 42748, 2.0: 40931, 3.0: 39270, 4.0: 37809, 5.0: 36038, 6.0: 34365, 7.0: 32640, 8.0: 31142, 9.0: 29601, 10.0: 28546, 11.0: 26774, 12.0: 25266, 13.0: 23721, 14.0: 22345})
