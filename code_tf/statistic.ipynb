# %%
import matplotlib.pyplot as plt
import numpy as np 
import os, sys
from collections import Counter

os.chdir('/share/Documents/project/onn-digital')
print(os.getcwd())

# npy_dir = 'log_tf/npy_e_noAdd3'
npy_dir = 'log_tf/10_64_round_clamp_floor_e_noAdd3_genInputs_quant/npy'
# Out:
# /share/Documents/project/onn-digital

# %%
def show(data, title):
    print(Counter(data))  # 直接显示数据出现频次
    print()

    plt.hist(data)
    plt.title(title)
    plt.show()

# %%
w1 = np.load(os.path.join(npy_dir, 'w1.npy')).reshape(-1)
show(w1, 'w1')
# Out:
# Counter({-3.0: 2025, 3.0: 1815, 0.0: 592, 1.0: 571, -1.0: 532, -2.0: 458, 2.0: 407})

# %%
w2 = np.load(os.path.join(npy_dir, 'w2.npy')).reshape(-1)
show(w2, 'w2')
# Out:
# Counter({3.0: 153, -3.0: 135, 0.0: 96, 1.0: 88, -1.0: 77, 2.0: 53, -2.0: 38})

# %%
frequency = np.load(os.path.join(npy_dir, 'frequency.npy')).reshape(-1)
show(frequency, 'frequency')
# Out:
# Counter({50.0: 478100, 200.0: 102962, 70.0: 5992, 90.0: 5731, 110.0: 5317, 130.0: 5053, 150.0: 4959, 190.0: 4638, 170.0: 4630, 60.0: 3943, 80.0: 3481, 100.0: 3301, 140.0: 3073, 120.0: 3054, 160.0: 2970, 180.0: 2796})

# %%
counters1 = np.load(os.path.join(npy_dir, 'counters1.npy')).reshape(-1)
show(counters1, 'counters1')
# Out:
# Counter({4.0: 718588, 5.0: 34188, 6.0: 26031, 7.0: 21371, 11.0: 18778, 12.0: 18532, 8.0: 18514, 10.0: 18171, 15.0: 18156, 13.0: 18141, 9.0: 18104, 14.0: 17994, 16.0: 17025, 17.0: 14875, 18.0: 11405, 19.0: 10127})

# %%
counters2 = np.load(os.path.join(npy_dir, 'counters2.npy')).reshape(-1)
show(counters2, 'counters2')
# Out:
# Counter({4.0: 478100, 19.0: 102962, 6.0: 5992, 8.0: 5731, 10.0: 5317, 12.0: 5053, 14.0: 4959, 18.0: 4638, 16.0: 4630, 5.0: 3943, 7.0: 3481, 9.0: 3301, 13.0: 3073, 11.0: 3054, 15.0: 2970, 17.0: 2796})

# %%
countersWdiv4n = np.load(os.path.join(npy_dir, 'countersWdiv4n.npy')).reshape(-1)
show(countersWdiv4n, 'countersWdiv4n')
# Out:
# Counter({-0.0: 478100, 15.0: 102962, 2.0: 5992, 4.0: 5731, 6.0: 5317, 8.0: 5053, 10.0: 4959, 14.0: 4638, 12.0: 4630, 1.0: 3943, 3.0: 3481, 5.0: 3301, 9.0: 3073, 7.0: 3054, 11.0: 2970, 13.0: 2796})

# %%
counters1_x_weight = np.load(os.path.join(npy_dir, 'counters1_x_weight.npy')).reshape(-1)
show(counters1_x_weight, 'counters1 x weight')
# Out:
