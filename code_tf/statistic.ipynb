# %%
import matplotlib.pyplot as plt
import numpy as np 
import os, sys
from collections import Counter

os.chdir('/share/Documents/project/onn-digital')
print(os.getcwd())

# npy_dir = 'log_tf/npy_e_noAdd3'
npy_dir = 'log_tf/npy_e_noAdd3_noChangeRelu'
# Out:
# /share/Documents/project/onn-digital

# %%
def show(data, title):
    print(Counter(data))  # 直接显示数据出现频次
    print()

    plt.hist(data)
    plt.title(title)
    plt.show()

# %%
w1 = np.load(os.path.join(npy_dir, 'w1.npy')).reshape(-1)
show(w1, 'w1')
# Out:
# Counter({-3.0: 14744, 3.0: 13346, 0.0: 5259, -1.0: 4972, 1.0: 4906, -2.0: 4056, 2.0: 3917})

# %%
w2 = np.load(os.path.join(npy_dir, 'w2.npy')).reshape(-1)
show(w2, 'w2')
# Out:
# Counter({-3.0: 1388, 3.0: 1378, 1.0: 521, 0.0: 521, -1.0: 495, 2.0: 432, -2.0: 385})

# %%
frequency = np.load(os.path.join(npy_dir, 'frequency.npy')).reshape(-1)
show(frequency, 'frequency')
# Out:
# Counter({50.0: 3719285, 200.0: 1088186, 60.0: 24975, 70.0: 24573, 80.0: 24130, 90.0: 23741, 100.0: 23419, 110.0: 22931, 120.0: 22508, 130.0: 22044, 140.0: 21683, 150.0: 21295, 160.0: 20947, 170.0: 20636, 180.0: 19935, 190.0: 19712})

# %%
counters1 = np.load(os.path.join(npy_dir, 'counters1.npy')).reshape(-1)
show(counters1, 'counters1')
# Out:
# Counter({4.0: 721116, 5.0: 35308, 6.0: 26874, 7.0: 21646, 12.0: 19720, 11.0: 19705, 10.0: 19678, 14.0: 19413, 8.0: 19325, 9.0: 19249, 13.0: 18887, 15.0: 18621, 16.0: 16382, 17.0: 12705, 18.0: 11056, 19.0: 315})

# %%
counters2 = np.load(os.path.join(npy_dir, 'counters2.npy')).reshape(-1)
show(counters2, 'counters2')
# Out:
# Counter({4.0: 3719285, 19.0: 1088186, 5.0: 24975, 6.0: 24573, 7.0: 24130, 8.0: 23741, 9.0: 23419, 10.0: 22931, 11.0: 22508, 12.0: 22044, 13.0: 21683, 14.0: 21295, 15.0: 20947, 16.0: 20636, 17.0: 19935, 18.0: 19712})

# %%
countersWdiv4n = np.load(os.path.join(npy_dir, 'countersWdiv4n.npy')).reshape(-1)
show(countersWdiv4n, 'countersWdiv4n')
# Out:
# Counter({0.0: 3719285, 15.0: 1088186, 1.0: 24975, 2.0: 24573, 3.0: 24130, 4.0: 23741, 5.0: 23419, 6.0: 22931, 7.0: 22508, 8.0: 22044, 9.0: 21683, 10.0: 21295, 11.0: 20947, 12.0: 20636, 13.0: 19935, 14.0: 19712})
